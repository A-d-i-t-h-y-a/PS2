# %%
# %matplotlib inline

import datacube
from deafrica_tools.plotting import rgb, display_map
import datacube
import odc.algo
import matplotlib.pyplot as plt
from datacube.utils.cog import write_cog

from deafrica_tools.plotting import display_map, rgb
dc = datacube.Datacube(app="04_Plotting")
#15.85828652, 80.78694696
#15.75418332, 81.02203692
lon_range  = (86.99979835697573, 88.11670526152713)
lat_range = (27.029820272857112, 28.025435531419042)
time_range = ('2022-01-15', '2023-04-18')
#display_map(x=lon_range, y=lat_range)
ds = dc.load(product="s2a_sen2cor_granule",
                 measurements=["B04_10m","B02_10m", "B03_10m","B11_20m","B12_20m","B08_10m"],
             x=lon_range,
             y=lat_range,
             time=time_range,
             output_crs='EPSG:6933',
             resolution=(-30, 30))

print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 3766, x: 3593)
# Coordinates:
#   * time         (time) datetime64[ns] 2023-04-17T05:01:00.412220
#   * y            (y) float64 3.438e+06 3.438e+06 ... 3.325e+06 3.325e+06
#   * x            (x) float64 8.394e+06 8.394e+06 ... 8.502e+06 8.502e+06
#     spatial_ref  int32 6933
# Data variables:
#     B04_10m      (time, y, x) uint16 0 8771 10913 11237 10494 ... 0 0 0 0 0
#     B02_10m      (time, y, x) uint16 0 8756 10890 11343 10518 ... 0 0 0 0 0
#     B03_10m      (time, y, x) uint16 0 8727 10916 11257 10438 ... 0 0 0 0 0
#     B11_20m      (time, y, x) uint16 0 1913 1775 1803 1842 1932 ... 0 0 0 0 0 0
#     B12_20m      (time, y, x) uint16 0 1893 1842 1879 1904 1981 ... 0 0 0 0 0 0
#     B08_10m      (time, y, x) uint16 0 8522 10393 10847 10125 ... 0 0 0 0 0
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
dataset = ds

rgb(ds, bands=[ "B04_10m","B02_10m", "B03_10m"], index=[0])

# %%
# convert dataset to float32 datatype so no-data values are set to NaN
dataset =  odc.algo.to_f32(dataset)

# Calculate the components that make up the NDVI calculation
band_diff = dataset.B03_10m - dataset.B11_20m
band_sum = dataset.B03_10m + dataset.B11_20m

# Calculate NDVI and store it as a measurement in the original dataset
ndvi = band_diff / band_sum
print("--------    ",ndvi)
# Out:
# --------     <xarray.DataArray (time: 1, y: 3766, x: 3593)>
# array([[[      nan, 0.6404135, 0.7202742, ...,       nan,       nan,
#                nan],
#         [      nan, 0.7043507, 0.7168597, ...,       nan,       nan,
#                nan],
#         [      nan, 0.7256791, 0.7251384, ...,       nan,       nan,
#                nan],
#         ...,
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan]]], dtype=float32)
# Coordinates:
#   * time         (time) datetime64[ns] 2023-04-17T05:01:00.412220
#   * y            (y) float64 3.438e+06 3.438e+06 ... 3.325e+06 3.325e+06
#   * x            (x) float64 8.394e+06 8.394e+06 ... 8.502e+06 8.502e+06
#     spatial_ref  int32 6933

# %%
plt.figure(figsize=(8, 8))
ndvi.plot(cmap="binary_r", vmin=-1, vmax=1, col_wrap=3)
plt.show()
