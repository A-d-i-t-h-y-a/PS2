# %%
# %matplotlib inline

import datacube
from deafrica_tools.plotting import rgb, display_map
import datacube
import datetime as dt
import odc.algo
import matplotlib.pyplot as plt
from datacube.utils.cog import write_cog
from deafrica_tools.datahandling import load_ard
from deafrica_tools.plotting import display_map, rgb
dc = datacube.Datacube(app="04_Plotting")
# 15.85828652, 80.78694696
# 15.75418332, 81.02203692
# lat_range = (15.75418332, 15.85828652)
# lon_range = (80.78694696, 81.02203692)
# time_range = ('2022-01-15', '2023-02-15')
lat = 15.80
lon = 80.90
buffer = 0.15
date = '2023-02-15'
latitude = (lat - buffer, lat + buffer)
longitude = (lon - buffer, lon + buffer)

# Specify the date range
# Calculated as today's date, subtract 730 days to collect two years of data
# Dates are converted to strings as required by loading function below
end_date = dt.datetime.strptime(date, "%Y-%m-%d")
start_date = end_date - dt.timedelta(days=730)

time = (start_date.strftime("%Y-%m-%d"), end_date.strftime("%Y-%m-%d"))
products = ["s2a_sen2cor_granule"]

query = {
    'x': longitude,
    'y': latitude,
    'time': time,
            'measurements': [
        'red',
        'green',
        'blue',
        'nir',
        'B11_20m'
    ],
    'output_crs': 'EPSG:6933',
    'resolution': (-20, 20)
}

# Load the data and mask out bad quality pixels
ds = load_ard(dc, products=products, min_gooddata=0.5, **query)
print(ds)
# Out:
# Using pixel quality parameters for Sentinel 2
# Finding datasets
#     s2a_sen2cor_granule
# Counting good quality pixels for each time step <class 'xarray.core.dataarray.DataArray'> <xarray.DataArray 'enum_to_bool-ba9e43cd-5fc53d378626c1a17cd03de35014172c' (
#                                                                             time: 2,
#                                                                             y: 1844,
#                                                                             x: 1448)>
# dask.array<enum_to_bool-ba9e43cd, shape=(2, 1844, 1448), dtype=bool, chunksize=(1, 1844, 1448), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 2022-08-23T05:14:41.977841 2023-02-09T...
#   * y            (y) float64 2.009e+06 2.009e+06 ... 1.972e+06 1.972e+06
#   * x            (x) float64 7.791e+06 7.791e+06 7.791e+06 ... 7.82e+06 7.82e+06
#     spatial_ref  int32 6933
# Attributes:
#     units:         1
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref
# Filtering to 2 out of 2 time steps with at least 50.0% good quality pixels
# Applying pixel quality/cloud mask
# Loading 2 time steps
# <xarray.Dataset>
# Dimensions:      (time: 2, y: 1844, x: 1448)
# Coordinates:
#   * time         (time) datetime64[ns] 2022-08-23T05:14:41.977841 2023-02-09T...
#   * y            (y) float64 2.009e+06 2.009e+06 ... 1.972e+06 1.972e+06
#   * x            (x) float64 7.791e+06 7.791e+06 7.791e+06 ... 7.82e+06 7.82e+06
#     spatial_ref  int32 6933
# Data variables:
#     red          (time, y, x) float32 2.028e+03 1.946e+03 ... 1.146e+03
#     green        (time, y, x) float32 2.07e+03 2.094e+03 ... 1.262e+03 1.27e+03
#     blue         (time, y, x) float32 1.769e+03 1.747e+03 ... 1.258e+03
#     nir          (time, y, x) float32 2.582e+03 2.844e+03 ... 1.09e+03 1.089e+03
#     B11_20m      (time, y, x) float32 1.677e+03 1.743e+03 ... 1.085e+03
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref
# /home/adithya/anaconda3/envs/odc_env/lib/python3.8/site-packages/rasterio/warp.py:344: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   _reproject(
# /home/adithya/anaconda3/envs/odc_env/lib/python3.8/site-packages/rasterio/warp.py:344: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   _reproject(

# %%
# Load the data from the Datacube
dataset = ds
# scl = ds['SCL_20m']
# clear_pixels = (scl != 3) & (scl != 8) & (scl != 9)
# print(clear_pixels)
# ndvi_masked = ndvi.where(clear_pixels)
# print(ndvi_masked)
rgb(ds, bands=['nir', 'red', 'green'], index=[0, 1])

# %%
# convert dataset to float32 datatype so no-data values are set to NaN
dataset =  odc.algo.to_f32(dataset)

# Calculate the components that make up the NDVI calculation
band_diff = dataset.nir - dataset.red
band_sum = dataset.nir + dataset.red

# Calculate NDVI and store it as a measurement in the original dataset
ndvi = band_diff / band_sum
print(ndvi)
# Out:
# <xarray.DataArray (time: 2, y: 1844, x: 1448)>
# array([[[ 0.12017354,  0.18747391,  0.25662252, ...,  0.10892308,
#           0.1745531 ,  0.25883168],
#         [ 0.15496689,  0.15293185,  0.22567622, ...,  0.15275063,
#           0.18721461,  0.1117759 ],
#         [ 0.48045978,  0.26488215,  0.18032786, ...,  0.19005917,
#           0.14550914,  0.18671364],
#         ...,
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[ 0.53325415,  0.5495627 ,  0.5105832 , ..., -0.00713267,
#           0.13078241,  0.2835165 ],
#         [ 0.53740275,  0.54678494,  0.51510507, ...,  0.08949174,
#           0.153219  ,  0.09417596],
#         [ 0.5508021 ,  0.525958  ,  0.57881284, ...,  0.20384718,
#           0.07533139,  0.2305726 ],
#         ...,
#         [-0.03002879, -0.03301295, -0.02410148, ..., -0.01934323,
#          -0.01577564, -0.02184574],
#         [-0.02441043, -0.03488372, -0.03078203, ..., -0.03112314,
#          -0.02981753, -0.01821413],
#         [-0.02275548, -0.04204452, -0.02134647, ..., -0.02821869,
#          -0.01535682, -0.02550336]]], dtype=float32)
# Coordinates:
#   * time         (time) datetime64[ns] 2022-08-23T05:14:41.977841 2023-02-09T...
#   * y            (y) float64 2.009e+06 2.009e+06 ... 1.972e+06 1.972e+06
#   * x            (x) float64 7.791e+06 7.791e+06 7.791e+06 ... 7.82e+06 7.82e+06
#     spatial_ref  int32 6933

# %%
plt.figure(figsize=(8, 8))
ndvi.plot(col='time', vmin=-1, vmax=1, col_wrap=2)
plt.show()
